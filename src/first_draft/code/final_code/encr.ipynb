# %%
from BB84 import BB84, CascadeReconcill
from Teleport import Teleport
from cryptography.fernet import Fernet



k = Fernet.generate_key()
k
# Out:
# b'3oCbEBWJCwuwvDKR664EavukNjvls0oZs7mzGoRRQaw='
